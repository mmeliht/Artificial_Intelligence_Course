# %% [markdown]
# <font color =red > Data Visialization - Veri Görselleştirme

# %% [markdown]
# Bu derste verileri grafiklerle gösterme konuları göreceğiz. Bar chart , pie chart , histogram etc.

# %%
import pandas as pd # verileri okuma paketi

# %%
df = pd.read_csv('combine.csv')

# %%
# EDA - eploratory data analysis - keşifçi veri analizi

# %%
df.head()
# Out:
#    year            name firstname   lastname position  heightfeet  \
# 0  2015  Ameer Abdullah     Ameer   Abdullah       RB           5
# 1  2015  Nelson Agholor    Nelson    Agholor       WR           6
# 2  2015       Jay Ajayi       Jay      Ajayi       RB           6
# 3  2015  Kwon Alexander      Kwon  Alexander      OLB           6
# 4  2015    Mario Alford     Mario     Alford       WR           5
#
#    heightinches  heightinchestotal  weight  arms  ...  vertical  broad  bench  \
# 0           9.0               69.0     205   0.0  ...      42.5    130     24
# 1           0.0               72.0     198   0.0  ...       0.0      0     12
# 2           0.0               72.0     221   0.0  ...      39.0    121     19
# 3           1.0               73.0     227   0.0  ...      36.0    121     24
# 4           8.0               68.0     180   0.0  ...      34.0    121     13
#
#    round        college  pick  pickround  picktotal  wonderlic  nflgrade
# ...

# %%
df.shape
# Out:
# (4947, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4947 entries, 0 to 4946
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               4947 non-null   int64
#  1   name               4947 non-null   object
#  2   firstname          4947 non-null   object
#  3   lastname           4947 non-null   object
#  4   position           4947 non-null   object
#  5   heightfeet         4947 non-null   int64
#  6   heightinches       4947 non-null   float64
#  7   heightinchestotal  4947 non-null   float64
#  8   weight             4947 non-null   int64
#  9   arms               4947 non-null   float64
#  10  hands              4947 non-null   float64
#  11  fortyyd            4947 non-null   float64
#  12  twentyyd           4947 non-null   float64
#  13  tenyd              4947 non-null   float64
#  14  twentyss           4947 non-null   float64
#  15  threecone          4947 non-null   float64
# ...

# %%
df.describe()
# Out:
#               year   heightfeet  heightinches  heightinchestotal       weight  \
# count  4947.000000  4947.000000   4947.000000        4947.000000  4947.000000
# mean   2007.132201     5.805337      4.371437          74.035476   245.579745
# std       5.029664     0.395981      3.279223           2.614778    45.639366
# min    1999.000000     5.000000      0.000000          65.000000   155.000000
# 25%    2003.000000     6.000000      2.000000          73.000000   208.000000
# 50%    2007.000000     6.000000      4.000000          74.000000   237.000000
# 75%    2012.000000     6.000000      6.000000          76.000000   289.000000
# max    2015.000000     6.000000     11.875000          82.000000   386.000000
#
#               arms        hands      fortyyd     twentyyd        tenyd  \
# count  4947.000000  4947.000000  4947.000000  4947.000000  4947.000000
# mean      7.640243     2.252426     4.610386     0.073734     0.129149
# ...

# %%
df.isnull().sum()  # hangi sütunda kaç boş veri var
# Out:
# year                    0
# name                    0
# firstname               0
# lastname                0
# position                0
# heightfeet              0
# heightinches            0
# heightinchestotal       0
# weight                  0
# arms                    0
# hands                   0
# fortyyd                 0
# twentyyd                0
# tenyd                   0
# twentyss                0
# threecone               0
# vertical                0
# broad                   0
# bench                   0
# round                   0
# college              1470
# pick                 1791
# pickround               0
# picktotal               0
# wonderlic               0
# nflgrade                0
# dtype: int64

# %%
df.describe().to_excel('istatistik.xlsx')

# %%
df.sample(5)
# Out:
#       year              name firstname  lastname position  heightfeet  \
# 58    2015    Landon Collins    Landon   Collins       SS           6
# 270   2015  JaCorey Shepherd   JaCorey  Shepherd       CB           5
# 1230  2012     Robert Turbin    Robert    Turbin       RB           5
# 3545  2003     Nate Burleson      Nate  Burleson       WR           6
# 0     2015    Ameer Abdullah     Ameer  Abdullah       RB           5
#
#       heightinches  heightinchestotal  weight  arms  ...  vertical  broad  \
# 58             0.0               72.0     228   0.0  ...      35.0    120
# 270           11.0               71.0     199   0.0  ...       0.0      0
# 1230          10.0               70.0     222  31.0  ...      36.0    122
# 3545           1.0               73.0     197   0.0  ...      42.5    126
# 0              9.0               69.0     205   0.0  ...      42.5    130
#
#       bench  round     college     pick  pickround  picktotal  wonderlic  \
# ...

# %%
df['college'] = df['college'].fillna('Pending')

# %%
df.isnull().sum()
# Out:
# year                    0
# name                    0
# firstname               0
# lastname                0
# position                0
# heightfeet              0
# heightinches            0
# heightinchestotal       0
# weight                  0
# arms                    0
# hands                   0
# fortyyd                 0
# twentyyd                0
# tenyd                   0
# twentyss                0
# threecone               0
# vertical                0
# broad                   0
# bench                   0
# round                   0
# college                 0
# pick                 1791
# pickround               0
# picktotal               0
# wonderlic               0
# nflgrade                0
# dtype: int64

# %%
df[df['position']=='OG']
# Out:
#       year            name firstname  lastname position  heightfeet  \
# 23    2015         Al Bond        Al      Bond       OG           6
# 35    2015   Trenton Brown   Trenton     Brown       OG           6
# 38    2015       A.J. Cann      A.J.      Cann       OG           6
# 89    2015   Jamil Douglas     Jamil   Douglas       OG           6
# 100   2015   Tayo Fabuluje      Tayo  Fabuluje       OG           6
# ...    ...             ...       ...       ...      ...         ...
# 4869  1999     Bobby Singh     Bobby     Singh       OG           6
# 4882  1999  Cameron Spikes   Cameron    Spikes       OG           6
# 4904  1999    Randy Thomas     Randy    Thomas       OG           6
# 4936  1999       Brad Winn      Brad      Winn       OG           6
# 4937  1999     Jerry Wisne     Jerry     Wisne       OG           6
#
#       heightinches  heightinchestotal  weight  arms  ...  vertical  broad  \
# 23             4.0               76.0     303   0.0  ...      23.5     90
# ...

# %%
df.weight.min() , df.weight.max() , df.weight.std() , df.weight.var() , df.weight.mean()
# Out:
# (155, 386, 45.6393660873356, 2082.951736853839, np.float64(245.57974530018194))

# %%
df.isnull().sum()
# Out:
# year                    0
# name                    0
# firstname               0
# lastname                0
# position                0
# heightfeet              0
# heightinches            0
# heightinchestotal       0
# weight                  0
# arms                    0
# hands                   0
# fortyyd                 0
# twentyyd                0
# tenyd                   0
# twentyss                0
# threecone               0
# vertical                0
# broad                   0
# bench                   0
# round                   0
# college                 0
# pick                 1791
# pickround               0
# picktotal               0
# wonderlic               0
# nflgrade                0
# dtype: int64

# %%
del df['pick']  # %80 ni boşsa silebiliriz

# %%
df.head()
# Out:
#    year            name firstname   lastname position  heightfeet  \
# 0  2015  Ameer Abdullah     Ameer   Abdullah       RB           5
# 1  2015  Nelson Agholor    Nelson    Agholor       WR           6
# 2  2015       Jay Ajayi       Jay      Ajayi       RB           6
# 3  2015  Kwon Alexander      Kwon  Alexander      OLB           6
# 4  2015    Mario Alford     Mario     Alford       WR           5
#
#    heightinches  heightinchestotal  weight  arms  ...  threecone  vertical  \
# 0           9.0               69.0     205   0.0  ...       6.79      42.5
# 1           0.0               72.0     198   0.0  ...       0.00       0.0
# 2           0.0               72.0     221   0.0  ...       7.10      39.0
# 3           1.0               73.0     227   0.0  ...       7.14      36.0
# 4           8.0               68.0     180   0.0  ...       6.64      34.0
#
#    broad  bench  round        college  pickround  picktotal  wonderlic  \
# ...

# %%
df['college'].value_counts()
# Out:
# college
# Pending                1470
# Georgia                  81
# Florida                  80
# USC                      77
# Alabama                  75
#                        ...
# Air Force                 1
# South Dakota State        1
# Saginaw Valley            1
# Southern University       1
# Fort Valley State         1
# Name: count, Length: 285, dtype: int64

# %%
# Data Visialization

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import random

# %%
x = np.arange(20)
y = np.random.normal(10,1,20)
z = np.random.normal(10,2,20)

# %%
plt.plot(x,y);
plt.plot(x,z);

# %%
fig =plt.figure(figsize=(10,6))
ax= fig.add_subplot(131)
ax.plot(x,y,c= 'red', marker='d')


bx=fig.add_subplot(132)
bx.scatter(x,y, marker='*')

cx=fig.add_subplot(133)
cx.hist(y)
# Out:
# (array([1., 3., 2., 4., 1., 0., 4., 0., 2., 3.]),
#  array([ 8.61323113,  8.97085288,  9.32847463,  9.68609637, 10.04371812,
#         10.40133987, 10.75896161, 11.11658336, 11.47420511, 11.83182685,
#         12.1894486 ]),
#  <BarContainer object of 10 artists>)

# %%
df = pd.read_csv('supermarket.csv')

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.tail(2)
# Out:
#       Invoice ID Branch    City Customer type  Gender         Product line  \
# 998  347-56-2442      A  Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A  Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time Payment    cogs  \
# 998       65.82         1   3.291   69.111  2/22/2019  15:33    Cash   65.82
# 999       88.34         7  30.919  649.299  2/18/2019  13:28    Cash  618.38
#
#      gross margin percentage  gross income  Rating
# 998                 4.761905         3.291     4.1
# 999                 4.761905        30.919     6.6

# %%
df.sample(2) #rastgele 400.00 bin datayı alır
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 369  254-31-0042      A    Yangon        Member    Male
# 339  374-17-3652      B  Mandalay        Member  Female
#
#                Product line  Unit price  Quantity  Tax 5%    Total      Date  \
# 369  Electronic accessories       21.50         9   9.675  203.175  3/6/2019
# 339      Food and beverages       42.82         9  19.269  404.649  2/5/2019
#
#       Time      Payment    cogs  gross margin percentage  gross income  Rating
# 369  12:46  Credit card  193.50                 4.761905         9.675     7.8
# 339  15:26  Credit card  385.38                 4.761905        19.269     8.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df['City'].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df['Total'].max()
# Out:
# 1042.65

# %%
df['Total'].min()
# Out:
# 10.6785

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
df['Day']=(df['Date']).dt.day
df['Month']=(df['Date']).dt.month
df['Year']=(df['Date']).dt.year
df['month_name']=df['Date'].dt.month_name()
df['weekday']=df['Date'].dt.day_name()
df['Time']=pd.to_datetime(df['Time']) 
df['Hour']=(df['Time']).dt.hour
# Out:
# C:\Users\melih\AppData\Local\Temp\ipykernel_8152\330908971.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time']=pd.to_datetime(df['Time'])

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  ...  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  ...
# 1  Electronic accessories       15.28         5   3.8200   80.2200  ...
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  ...
# 3       Health and beauty       58.22         8  23.2880  489.0480  ...
# 4       Sports and travel       86.31         7  30.2085  634.3785  ...
#
#      cogs gross margin percentage gross income  Rating  Day  Month  Year  \
# 0  522.83                4.761905      26.1415     9.1    5      1  2019
# ...

# %%
sns.countplot(x=df['month_name'],hue=df['month_name'])   
plt.xticks(rotation=90);

# %%
sns.countplot(x=df['Branch'] ,hue = df['Branch'])
# Out:
# <Axes: xlabel='Branch', ylabel='count'>

# %%
sns.countplot(x=df['Gender'] ,hue = df['Gender'])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df['Gender'].value_counts(normalize = True)
# Out:
# Gender
# Female    0.501
# Male      0.499
# Name: proportion, dtype: float64

# %%
sns.countplot(x = df['weekday']) 
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Saturday'),
#   Text(1, 0, 'Friday'),
#   Text(2, 0, 'Sunday'),
#   Text(3, 0, 'Monday'),
#   Text(4, 0, 'Thursday'),
#   Text(5, 0, 'Wednesday'),
#   Text(6, 0, 'Tuesday')])

# %%
print(df['Date'].dtype)
# Out:
# datetime64[ns]

# %%
print(df['Date'].dt.day_name().value_counts())
# Out:
# Date
# Saturday     164
# Tuesday      158
# Wednesday    143
# Friday       139
# Thursday     138
# Sunday       133
# Monday       125
# Name: count, dtype: int64

# %%
df['month_name'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
print(df['Date'].dt.month_name().value_counts())
# Out:
# Date
# January     352
# March       345
# February    303
# Name: count, dtype: int64

# %%
sns.countplot(x= df["Payment"])
# Out:
# <Axes: xlabel='Payment', ylabel='count'>

# %%
df['Product line'].value_counts().plot.pie(autopct = '%1.1f%%', explode=[0.1,0,0,0,0,0]);
