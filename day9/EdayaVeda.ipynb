# %%
import pandas as pd

# %%
df = pd.read_excel('cars.xls')

# %%
df.head()
# Out:
#           Price  Mileage   Make    Model      Trim   Type  Cylinder  Liter  \
# 0  17314.103129     8221  Buick  Century  Sedan 4D  Sedan         6    3.1
# 1  17542.036083     9135  Buick  Century  Sedan 4D  Sedan         6    3.1
# 2  16218.847862    13196  Buick  Century  Sedan 4D  Sedan         6    3.1
# 3  16336.913140    16342  Buick  Century  Sedan 4D  Sedan         6    3.1
# 4  16339.170324    19832  Buick  Century  Sedan 4D  Sedan         6    3.1
#
#    Doors  Cruise  Sound  Leather
# 0      4       1      1        1
# 1      4       1      1        0
# 2      4       1      1        0
# 3      4       1      0        0
# 4      4       1      0        1

# %%
#####

# %%
#pip install summarytools Eda nın tüm sütunlara tek tek yapılmış hali

# %%
from summarytools import dfSummary

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_12c75 thead>tr>th {
#   text-align: left;
# }
# #T_12c75_row0_col0, #T_12c75_row1_col0, #T_12c75_row2_col0, #T_12c75_row3_col0, #T_12c75_row4_col0, #T_12c75_row5_col0, #T_12c75_row6_col0, #T_12c75_row7_col0, #T_12c75_row8_col0, #T_12c75_row9_col0, #T_12c75_row10_col0, #T_12c75_row11_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_12c75_row0_col1, #T_12c75_row1_col1, #T_12c75_row2_col1, #T_12c75_row3_col1, #T_12c75_row4_col1, #T_12c75_row5_col1, #T_12c75_row6_col1, #T_12c75_row7_col1, #T_12c75_row8_col1, #T_12c75_row9_col1, #T_12c75_row10_col1, #T_12c75_row11_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_12c75_row0_col2, #T_12c75_row1_col2, #T_12c75_row2_col2, #T_12c75_row3_col2, #T_12c75_row4_col2, #T_12c75_row5_col2, #T_12c75_row6_col2, #T_12c75_row7_col2, #T_12c75_row8_col2, #T_12c75_row9_col2, #T_12c75_row10_col2, #T_12c75_row11_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_12c75_row0_col3, #T_12c75_row1_col3, #T_12c75_row2_col3, #T_12c75_row3_col3, #T_12c75_row4_col3, #T_12c75_row5_col3, #T_12c75_row6_col3, #T_12c75_row7_col3, #T_12c75_row8_col3, #T_12c75_row9_col3, #T_12c75_row10_col3, #T_12c75_row11_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_12c75_row0_col4, #T_12c75_row1_col4, #T_12c75_row2_col4, #T_12c75_row3_col4, #T_12c75_row4_col4, #T_12c75_row5_col4, #T_12c75_row6_col4, #T_12c75_row7_col4, #T_12c75_row8_col4, #T_12c75_row9_col4, #T_12c75_row10_col4, #T_12c75_row11_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_12c75_row0_col5, #T_12c75_row1_col5, #T_12c75_row2_col5, #T_12c75_row3_col5, #T_12c75_row4_col5, #T_12c75_row5_col5, #T_12c75_row6_col5, #T_12c75_row7_col5, #T_12c75_row8_col5, #T_12c75_row9_col5, #T_12c75_row10_col5, #T_12c75_row11_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_12c75">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 804 x 12<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_12c75_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_12c75_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_12c75_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_12c75_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_12c75_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_12c75_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_12c75_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_12c75_row0_col1" class="data row0 col1" ><strong>Price</strong><br>[float64]</td>
#       <td id="T_12c75_row0_col2" class="data row0 col2" >Mean (sd) : 21343.1 (9884.9)<br>min < med < max:<br>8638.9 < 18025.0 < 70755.5<br>IQR (CV) : 12444.2 (2.2)</td>
#       <td id="T_12c75_row0_col3" class="data row0 col3" >798 distinct values</td>
#       <td id="T_12c75_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_12c75_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_12c75_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_12c75_row1_col1" class="data row1 col1" ><strong>Mileage</strong><br>[int64]</td>
#       <td id="T_12c75_row1_col2" class="data row1 col2" >Mean (sd) : 19831.9 (8196.3)<br>min < med < max:<br>266.0 < 20913.5 < 50387.0<br>IQR (CV) : 10589.5 (2.4)</td>
#       <td id="T_12c75_row1_col3" class="data row1 col3" >791 distinct values</td>
#       <td id="T_12c75_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_12c75_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_12c75_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_12c75_row2_col1" class="data row2 col1" ><strong>Make</strong><br>[object]</td>
#       <td id="T_12c75_row2_col2" class="data row2 col2" >1. Chevrolet<br>2. Pontiac<br>3. SAAB<br>4. Buick<br>5. Cadillac<br>6. Saturn</td>
#       <td id="T_12c75_row2_col3" class="data row2 col3" >320 (39.8%)<br>150 (18.7%)<br>114 (14.2%)<br>80 (10.0%)<br>80 (10.0%)<br>60 (7.5%)</td>
#       <td id="T_12c75_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_12c75_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_12c75_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_12c75_row3_col1" class="data row3 col1" ><strong>Model</strong><br>[object]</td>
#       <td id="T_12c75_row3_col2" class="data row3 col2" >1. AVEO<br>2. Cavalier<br>3. Malibu<br>4. Cobalt<br>5. Ion<br>6. 9_3 HO<br>7. Impala<br>8. Lacrosse<br>9. Grand Prix<br>10. Bonneville<br>11. other</td>
#       <td id="T_12c75_row3_col3" class="data row3 col3" >60 (7.5%)<br>60 (7.5%)<br>60 (7.5%)<br>50 (6.2%)<br>50 (6.2%)<br>40 (5.0%)<br>30 (3.7%)<br>30 (3.7%)<br>30 (3.7%)<br>30 (3.7%)<br>364 (45.3%)</td>
#       <td id="T_12c75_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_12c75_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_12c75_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_12c75_row4_col1" class="data row4 col1" ><strong>Trim</strong><br>[object]</td>
#       <td id="T_12c75_row4_col2" class="data row4 col2" >1. Sedan 4D<br>2. LS Sedan 4D<br>3. Coupe 2D<br>4. LS Coupe 2D<br>5. LT Sedan 4D<br>6. GT Sedan 4D<br>7. SE Sedan 4D<br>8. Aero Sedan 4D<br>9. Arc Sedan 4D<br>10. Quad Coupe 2D<br>11. other</td>
#       <td id="T_12c75_row4_col3" class="data row4 col3" >170 (21.1%)<br>50 (6.2%)<br>50 (6.2%)<br>30 (3.7%)<br>30 (3.7%)<br>20 (2.5%)<br>20 (2.5%)<br>20 (2.5%)<br>20 (2.5%)<br>20 (2.5%)<br>374 (46.5%)</td>
#       <td id="T_12c75_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_12c75_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_12c75_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_12c75_row5_col1" class="data row5 col1" ><strong>Type</strong><br>[object]</td>
#       <td id="T_12c75_row5_col2" class="data row5 col2" >1. Sedan<br>2. Coupe<br>3. Wagon<br>4. Hatchback<br>5. Convertible</td>
#       <td id="T_12c75_row5_col3" class="data row5 col3" >490 (60.9%)<br>140 (17.4%)<br>64 (8.0%)<br>60 (7.5%)<br>50 (6.2%)</td>
#       <td id="T_12c75_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_12c75_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_12c75_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_12c75_row6_col1" class="data row6 col1" ><strong>Cylinder</strong><br>[int64]</td>
#       <td id="T_12c75_row6_col2" class="data row6 col2" >1. 4<br>2. 6<br>3. 8</td>
#       <td id="T_12c75_row6_col3" class="data row6 col3" >394 (49.0%)<br>310 (38.6%)<br>100 (12.4%)</td>
#       <td id="T_12c75_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_12c75_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_12c75_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_12c75_row7_col1" class="data row7 col1" ><strong>Liter</strong><br>[float64]</td>
#       <td id="T_12c75_row7_col2" class="data row7 col2" >Mean (sd) : 3.0 (1.1)<br>min < med < max:<br>1.6 < 2.8 < 6.0<br>IQR (CV) : 1.6 (2.7)</td>
#       <td id="T_12c75_row7_col3" class="data row7 col3" >16 distinct values</td>
#       <td id="T_12c75_row7_col4" class="data row7 col4" ><img src = "......"></img></td>
#       <td id="T_12c75_row7_col5" class="data row7 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_12c75_row8_col0" class="data row8 col0"

# %%
#pip install sweetviz daha görsellik ağırlıklı

# %%
# import sweetviz as sv

# %%
# eda = sv.analyze(df, target_feat = 'Price')
