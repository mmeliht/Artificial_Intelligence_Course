# %%
import pandas as pd

# %%
df = pd.read_excel('cars.xls')

# %%
df.head()
# Out:
#           Price  Mileage   Make    Model      Trim   Type  Cylinder  Liter  \
# 0  17314.103129     8221  Buick  Century  Sedan 4D  Sedan         6    3.1
# 1  17542.036083     9135  Buick  Century  Sedan 4D  Sedan         6    3.1
# 2  16218.847862    13196  Buick  Century  Sedan 4D  Sedan         6    3.1
# 3  16336.913140    16342  Buick  Century  Sedan 4D  Sedan         6    3.1
# 4  16339.170324    19832  Buick  Century  Sedan 4D  Sedan         6    3.1
#
#    Doors  Cruise  Sound  Leather
# 0      4       1      1        1
# 1      4       1      1        0
# 2      4       1      1        0
# 3      4       1      0        0
# 4      4       1      0        1

# %%
#####

# %%
#pip install summarytools Eda nın tüm sütunlara tek tek yapılmış hali

# %%
from summarytools import dfSummary

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_e4ada thead>tr>th {
#   text-align: left;
# }
# #T_e4ada_row0_col0, #T_e4ada_row1_col0, #T_e4ada_row2_col0, #T_e4ada_row3_col0, #T_e4ada_row4_col0, #T_e4ada_row5_col0, #T_e4ada_row6_col0, #T_e4ada_row7_col0, #T_e4ada_row8_col0, #T_e4ada_row9_col0, #T_e4ada_row10_col0, #T_e4ada_row11_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_e4ada_row0_col1, #T_e4ada_row1_col1, #T_e4ada_row2_col1, #T_e4ada_row3_col1, #T_e4ada_row4_col1, #T_e4ada_row5_col1, #T_e4ada_row6_col1, #T_e4ada_row7_col1, #T_e4ada_row8_col1, #T_e4ada_row9_col1, #T_e4ada_row10_col1, #T_e4ada_row11_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# ...

# %%
#pip install sweetviz daha görsellik ağırlıklı eda

# %%
#import sweetviz as sv

# %%
# eda = sv.analyze(df, target_feat = 'Price')

# %%
#from sklearn.model_selection import train_test_split

# %%
#train_df , test_df = train_test_split(df, train_size = 0.75 )

# %%
#compare = sv.compare(source=train_df, compare=test_df, target_feat="Price")
#compare.show_html('Compare.html')

# %%
pip install dtale
# Out:
# ...
#      ---------------------------------------- 0.0/642.7 kB ? eta -:--:--
#      ------------------------------ ------- 524.3/642.7 kB 5.5 MB/s eta 0:00:01
#      -------------------------------------- 642.7/642.7 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/17.6 MB ? eta -:--:--
#    --------------------- ------------------ 9.4/17.6 MB 45.5 MB/s eta 0:00:01
#    ---------------------------------------- 17.6/17.6 MB 58.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 7.8/7.8 MB 87.8 MB/s eta 0:00:00
# ...
#   Created wheel for dash_daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669718 sha256=a36851a3a12021475816346213cbed795b760725459e254b2679f998c5a1f7c1
# ...

# %%
import dtale
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\kaleido\__init__.py:14: UserWarning:
#
#
#
# ...
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.

# %%
##sweetviz gibi görsel bir arayüz. sweetviz çalışmadığı için bunu kullanabilirim

d = dtale.show(df)
d.open_browser()

# %%
#pip install autoviz

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
AV = AutoViz_Class()

# %%
datapath = ''
filename = 'cars.xls'
sep = ','
target = 'Price'

# %%
dft = AV.AutoViz(datapath+filename, sep, depVar=target, dfte="",
           header=0, verbose=1,
            lowess=False,chart_format='bokeh',max_rows_analyzed=150000,max_cols_analyzed=30)
# Out:
# Shape of your Data Set loaded: (804, 12)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  1
#     Number of Integer-Categorical Columns =  2
#     Number of String-Categorical Columns =  4
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  4
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     11 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
#
# ...
