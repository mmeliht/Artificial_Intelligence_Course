# %%
#pip install pycaret

# %%
import pandas as pd
from pycaret.regression import *

# %%
df = pd.read_pickle('kc_house.pkl')

# %%
# Regression

# %%
setup(df , target= 'price')

# %%
best_model = compare_models()# en iyi makneğremesi modelini bulur

# %%
# Classification

# %%
df=pd.read_csv('pima-indians-diabetes.csv')

# %%
from pycaret.classification import *

# %%
setup(df,target='Outcome')

# %%
compare_models()# en iyi makneğremesi modelini bulur
# Out:
# <style type="text/css">
# #T_a84f8 th {
#   text-align: left;
# }
# ...

# %%
best_model = create_model('lr')
# Out:
# <style type="text/css">
# #T_f6c49_row10_col0, #T_f6c49_row10_col1, #T_f6c49_row10_col2, #T_f6c49_row10_col3, #T_f6c49_row10_col4, #T_f6c49_row10_col5, #T_f6c49_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f6c49" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6c49_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f6c49_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f6c49_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f6c49_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f6c49_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f6c49_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f6c49_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
plot_model(best_model,plot='feature')

# %%
plot_model(best_model,plot='auc')

# %%
plot_model(best_model,plot='confusion_matrix')

# %%
plot_model(best_model,plot='learning')

# %%
plot_model(best_model,plot='boundary')

# %%
# Clustering

# %%
df = pd.read_excel('cars.xls')

# %%
from pycaret.clustering import *

# %%
setup(df)
# Out:
# <style type="text/css">
# #T_85800_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_85800" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85800_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_85800_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85800_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85800_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_85800_row0_col1" class="data row0 col1" >8815</td>
#     </tr>
#     <tr>
#       <th id="T_85800_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_85800_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_85800_row1_col1" class="data row1 col1" >(804, 12)</td>
#     </tr>
#     <tr>
# ...

# %%
 kmeans = create_model('kmeans',4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a8bbd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8bbd_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a8bbd_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a8bbd_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a8bbd_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a8bbd_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a8bbd_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8bbd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8bbd_row0_col0" class="data row0 col0" >0.4134</td>
#       <td id="T_a8bbd_row0_col1" class="data row0 col1" >600.9826</td>
# ...

# %%
plot_model(kmeans)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(kmeans, plot="elbow")

# %%
plot_model(kmeans, plot="tsne")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# deep learning için autokeras var !!!!!!!!!!!!!

# %%
models()
# Out:
#                                        Name  \
# ID
# kmeans                   K-Means Clustering
# ap                     Affinity Propagation
# meanshift             Mean Shift Clustering
# sc                      Spectral Clustering
# hclust             Agglomerative Clustering
# dbscan     Density-Based Spatial Clustering
# optics                    OPTICS Clustering
# birch                      Birch Clustering
#
#                                                    Reference
# ID
# kmeans                        sklearn.cluster._kmeans.KMeans
# ap         sklearn.cluster._affinity_propagation.Affinity...
# meanshift              sklearn.cluster._mean_shift.MeanShift
# sc              sklearn.cluster._spectral.SpectralClustering
# hclust     sklearn.cluster._agglomerative.AgglomerativeCl...
# dbscan                        sklearn.cluster._dbscan.DBSCAN
# optics                        sklearn.cluster._optics.OPTICS
# birch                           sklearn.cluster._birch.Birch

# %%
plot_model(kmeans, plot="silhouette")

# %%
plot_model(kmeans, plot="distance")

# %%
plot_model(kmeans, plot="distribution")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
save_model(kmeans,'kmeans_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Price', 'Mileage', 'Cylinder',
#                                               'Liter', 'Doors', 'Cruise',
#                                               'Sound', 'Leather'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categorical_imputer',
#                   Transformer...
# ...
