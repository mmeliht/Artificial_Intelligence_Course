# %%
from bs4 import BeautifulSoup as soup

# %%
import requests

# %%
# Kendi yerel serverimizden veri çektik. python serverin çalışıyor olması lazım
page = requests.get('http://localhost:8080/')

# %%
page.content
# Out:
# b'<html>\r\n    <head>\r\n        <meta charset="utf8">\r\n        <title> Benim ilk web sayfam </title>\r\n    </head>\r\n    <body>\r\n    <h1> Benim duygusal websiteme ho\xc5\x9fgeldiniz</h1>\r\n    <marquee direction="left"><font size=7 color="red">Merhaba D\xc3\xbcnya</font></marquee>\r\n    <marquee direction="right"><font size=7 color=green>Merhaba D\xc3\xbcnya</font></marquee>\r\n    <h2> Sessiz gemi </h2>\r\n    <p> <pre>\r\nArt\xc4\xb1k demir almak g\xc3\xbcn\xc3\xbc gelmi\xc5\x9fse zamandan\r\n\r\nMe\xc3\xa7hule giden bir gemi kalkar bu limandan.\r\n\r\nHi\xc3\xa7 yolcusu yokmu\xc5\x9f gibi sessizce al\xc4\xb1r yol;\r\n\r\nSallanmaz o kalk\xc4\xb1\xc5\x9fta ne mendil, ne de bir kol.\r\n\r\nR\xc4\xb1ht\xc4\xb1mda kalanlar bu seyahatten elemli,\r\n\r\nG\xc3\xbcnlerce siyah ufka bakar g\xc3\xb6zleri nemli,\r\n\r\nBi\xc3\xa7are g\xc3\xb6n\xc3\xbcller! Ne giden son gemidir bu!\r\n\r\nHicranl\xc4\xb1 hayat\xc4\xb1n ne de son matemidir bu.\r\n\r\nD\xc3\xbcnyada sevilmi\xc5\x9f ve seven nafile bekler;\r\n\r\nBilmez ki giden sevgililer d\xc3\xb6nmeyecekler.\r\n\r\nBir\xc3\xa7ok gidenin her biri memnun ki yerinden,\r\n\r\nBir\xc3\xa7ok seneler ge\xc3\xa7ti; d\xc3\xb6nen yok seferinden.\r\n</pre>\r\n</p>\r\n    </body>\r\n</html>'

# %%
sp = soup(page.content , 'html.parser')

# %%
sp.prettify
# Out:
# <bound method Tag.prettify of <html>
# <head>
# <meta charset="utf-8"/>
# <title> Benim ilk web sayfam </title>
# </head>
# <body>
# <h1> Benim duygusal websiteme hoşgeldiniz</h1>
# <marquee direction="left"><font color="red" size="7">Merhaba Dünya</font></marquee>
# <marquee direction="right"><font color="green" size="7">Merhaba Dünya</font></marquee>
# <h2> Sessiz gemi </h2>
# <p> <pre>
# Artık demir almak günü gelmişse zamandan
#
# Meçhule giden bir gemi kalkar bu limandan.
#
# Hiç yolcusu yokmuş gibi sessizce alır yol;
#
# Sallanmaz o kalkışta ne mendil, ne de bir kol.
#
# Rıhtımda kalanlar bu seyahatten elemli,
#
# Günlerce siyah ufka bakar gözleri nemli,
#
# Biçare gönüller! Ne giden son gemidir bu!
#
# Hicranlı hayatın ne de son matemidir bu.
#
# Dünyada sevilmiş ve seven nafile bekler;
#
# Bilmez ki giden sevgililer dönmeyecekler.
#
# Birçok gidenin her biri memnun ki yerinden,
#
# Birçok seneler geçti; dönen yok seferinden.
# </pre>
# </p>
# </body>
# </html>>

# %%
siir = sp.find('p')

# %%
siir
# Out:
# <p> <pre>
# Artık demir almak günü gelmişse zamandan
#
# Meçhule giden bir gemi kalkar bu limandan.
#
# Hiç yolcusu yokmuş gibi sessizce alır yol;
#
# Sallanmaz o kalkışta ne mendil, ne de bir kol.
#
# Rıhtımda kalanlar bu seyahatten elemli,
#
# Günlerce siyah ufka bakar gözleri nemli,
#
# Biçare gönüller! Ne giden son gemidir bu!
#
# Hicranlı hayatın ne de son matemidir bu.
#
# Dünyada sevilmiş ve seven nafile bekler;
#
# Bilmez ki giden sevgililer dönmeyecekler.
#
# Birçok gidenin her biri memnun ki yerinden,
#
# Birçok seneler geçti; dönen yok seferinden.
# </pre>
# </p>

# %%
page=requests.get('https://www.karar.com/yazarlar/zafer-acar/herkes-nerede-7320')

# %%
page.content

# %%
soup = soup(page.content , 'html.parser')

# %%
soup.prettify

# %%
soup.select('h1.content-title')[0].text
# Out:
# 'Herkes nerede?'

# %%
soup.select('article.article-content')[0].text

# %%
page=requests.get('https://www.karar.com/yazarlar/zafer-acar')

# %%
# Tüm yazıları alma

# %%
from bs4 import BeautifulSoup as soup

# %%
soup = soup(page.content , 'html.parser')

# %%
soup.prettify

# %%
linkler = soup.find_all('article', {'class': 'item box-shadow'})

# %%
linkler

# %%
from bs4 import BeautifulSoup as soup
yazilar=[]
basliklar=[]
for link in linkler:
    link1='https://www.karar.com'+link.a.get('href')
    baslik=link.h3.text
    page2=requests.get(link1)
    soup2=soup(page2.content, 'html.parser')
    makale=soup2.select('article.article-content')[0].text
    yazilar.append(makale)
    basliklar.append(baslik)

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Title': basliklar , 'Article': yazilar})

# %%
df.head()
# Out:
#                            Title  \
# 0  Engellilerin umudu yapay zeka
# 1             Kuantum yapay zeka
# 2                   Astronot 001
# 3   Çin’in uzay programı tam gaz
# 4    Yapay zeka ile çip tasarımı
#
#                                              Article
# 0  \n\nYapay zeka her alanda büyük değişimler ve ...
# 1  \n\nTeknolojik gelişmeler baş döndürücü hızla ...
# 2  \n\nUzay çalışmaları ve uçuşları küçüklüğümden...
# 3  \n\nUzay çalışmalarında ne kadar ileride iseni...
# 4  \n\nGeçtiğimiz hafta Google, bilgisayar çipler...
