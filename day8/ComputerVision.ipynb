# %% [markdown]
# # Computer Vision - Bilgisayarli Goru Bilgisayarin Gozu

# %%
#pip install opencv-python

# %%
import cv2

# %%
import numpy as np

# %%
resim=cv2.imread('input.jpg') # resim dosyasini rakam olarak okuma
cv2.imshow('Merhaba',resim)
cv2.waitKey() #bir tusa basana kadar bekle
cv2.destroyAllWindows()

# %%
resim.shape

# %%
import matplotlib.pyplot as plt

# %%
checkboard=np.zeros((9,9))
checkboard[0::2,1::2]=1
checkboard[1::2,0::2]=1
print(checkboard)

# %%
import matplotlib.image as mpig

# %%
plt.imshow(checkboard, cmap='gray',interpolation = 'nearest')

# %%
from skimage import data

# %%
bush = data.lfw_subset()

# %%
bush = bush[0,:,:]

# %%
bush

# %%
plt.figure(figsize=(3,3))
plt.imshow(bush , cmap='gray')

# %%
image = data.astronaut()
plt.imshow(image)

# %%
image=cv2.imread('input.jpg')

sb=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

cv2.imshow('Original',image)
cv2.waitKey()
cv2.imshow('Siyah Beyaz',sb)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
image=cv2.imread('input.jpg', 0) # 0 yazarsak doğrudan siyah beyaz okur
cv2.imshow('Siyah Beyaz',sb)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# insan gözü gibi okuma hsv kütüphanesi
image=cv2.imread('input.jpg')

hsv=cv2.cvtColor(image,cv2.COLOR_BGR2HSV)

cv2.imshow('Original',image)
cv2.waitKey()
cv2.imshow('HSB',hsv)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# hsv ile tek farkı resmin saturasyon kanallarını gösterir
image=cv2.imread('input.jpg')

hsv_image=cv2.cvtColor(image,cv2.COLOR_BGR2HSV)

cv2.imshow("HSV image",hsv_image[:,:,:])
cv2.imshow("Hue channel",hsv_image[:,:,0])
cv2.imshow("Saturation channel",hsv_image[:,:,1])
cv2.imshow("Calue channel",hsv_image[:,:,2])
cv2.waitKey()
cv2.destroyAllWindows()

# %%
image = cv2.imread("input.jpg")
B,G,R =cv2.split(image)
print(B.shape)
cv2.imshow("Red",R)
cv2.imshow("Green",G)
cv2.imshow("Blue",B)
cv2.waitKey(0)
cv2.destroyAllWindows()
merged = cv2.merge([B,G,R])
cv2.imshow("Merged",merged)
merged= cv2.merge([B+100,G,R+100])
cv2.imshow("Merged with Blue Amplified",merged)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Otonom araclar yallarini nasıl bulur

# %%
image = cv2.imread('input.jpg',0)

height,width = image.shape[:2]

sobel_x = cv2.Sobel(image,cv2.CV_64F,0,1,ksize = 5)
sobel_y = cv2.Sobel(image,cv2.CV_64F,1,0,ksize = 5)

cv2.imshow('Rotated Image',image)
cv2.waitKey(0)
cv2.imshow('Sobel X',sobel_x)
cv2.waitKey(0)
cv2.imshow('Sobel Y',sobel_y)
cv2.waitKey(0)

sobel_OR = cv2.bitwise_or(sobel_x,sobel_y)
cv2.imshow('sobel_OR',sobel_OR)
cv2.waitKey(0)

laplacian = cv2.Laplacian(image,cv2.CV_64F)
cv2.imshow('Laplacian',laplacian)
cv2.waitKey(0)

canny = cv2.Canny(image,50,120)
cv2.imshow('Canny',canny)
cv2.waitKey(0)


cv2.destroyAllWindows()

## arabaların şeritlerini bulmasını sağlıyor

# %%
# kamera açılır ve canlı olarak sketch halimizi görürüz.
def sketch(image):
    img_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

    img_gray_blur = cv2.GaussianBlur(img_gray,(5,5),0)
    canny_edges = cv2.Canny(img_gray_blur,10,70)
    ret,mask = cv2.threshold(canny_edges,250,255,cv2.THRESH_BINARY_INV)
    return mask

cap = cv2.VideoCapture(0)

while True:
    ret,frame = cap.read()
    cv2.imshow('Our live Sketcher',sketch(frame))
    if cv2.waitKey(1) == 13:
        break
cap.release()
cv2.destroyAllWindows()
print('done')

# %%
# Where is Waldo 
image=cv2.imread('WaldoBeach.jpg')

cv2.imshow('Where is Waldo',image)
cv2.waitKey()
gray=cv2.imread('WaldoBeach.jpg',0)
waldo=cv2.imread('Waldo.jpg',0)

result=cv2.matchTemplate(gray,waldo,cv2.TM_CCOEFF)
minval, maxval,minloc,maxloc=cv2.minMaxLoc(result)

top_left=maxloc
bottom_right=(top_left[0]+50,top_left[1]+50)
cv2.rectangle(image,top_left,bottom_right,(0,0,255),5)

cv2.imshow('Where is Waldo',image)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
pip install imutils

# %%
import imutils # fotoyu sağa sol aaşağı yukarı yansımasını alıyor
image = cv2.imread('input.jpg')
cv2.imshow('Original',image)

flipped = cv2.flip(image , 1)
cv2.imshow('Horizontal Original',flipped)

flipped = cv2.flip(image , 0)
cv2.imshow('Vertical Original',flipped)

flipped = cv2.flip(image , -1)
cv2.imshow('Bot Original',flipped)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# kamerayı açma ve q ile kapatma
cap=cv2.VideoCapture(0)
while True:
    ret,frame=cap.read()
    if ret:
        cv2.imshow('Bendeniz',frame)
    else:
        break
    key=cv2.waitKey(1)
    if key==ord('q'):
        break

# %%
'''
## videoyı oynatma

cap=cv2.VideoCapture('cars.mp4')
while True:
    ret,frame=cap.read()
    if ret:
        cv2.imshow('Bendeniz',frame)
    else:
        break
    key=cv2.waitKey(1)
    if key==ord('q'):
        break
'''

# %%
selfie=cv2.VideoCapture(0).read()[1]
cv2.imwrite('ben.jpg',selfie)
