# %% [markdown]
# # Skin Cancer Classification

# %% [markdown]
# Bu projede deri kanseri algilayan bir model gelistiriyoruz.

# %%
import cv2
import pandas as pd
import os
import numpy as np
from sklearn.model_selection import train_test_split

from
