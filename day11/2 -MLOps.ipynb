# %% [markdown]
# # Machine LEarning Project

# %% [markdown]
# #### Bu derste eğitilen modelleri kaydedip uygulama içerisinde kullanmayı öğreneceğiz

# %%
import pandas as pd

# %%
df = pd.read_csv('hiring.csv')

# %%
df.head()
# Out:
#   experience  test_score  interview_score  salary
# 0        NaN         8.0                9   50000
# 1        NaN         8.0                6   45000
# 2       five         6.0                7   60000
# 3        two        10.0               10   65000
# 4      seven         9.0                6   70000

# %%
import seaborn as sns

# %%
sns.countplot(x = df['experience'] , hue = df['experience'])
# Out:
# <Axes: xlabel='experience', ylabel='count'>

# %%
d = {'two' : 2, 'three': 3 , 'five': 5 , 'seven': 7 , 'eigth' : 8 , 'ten': 10 ,'eleven': 11}

# %%
df['experience'] = df['experience'].map(d)

# %%
df.head()
# Out:
#    experience  test_score  interview_score  salary
# 0         NaN         8.0                9   50000
# 1         NaN         8.0                6   45000
# 2         5.0         6.0                7   60000
# 3         2.0        10.0               10   65000
# 4         7.0         9.0                6   70000

# %%
df['experience'] = df['experience'].fillna(0)

# %%
df.isna().sum()
# Out:
# experience         0
# test_score         1
# interview_score    0
# salary             0
# dtype: int64

# %%
df['test_score'] = df['test_score'].fillna(df['test_score'].median())

# %%
df.isna().sum()
# Out:
# experience         0
# test_score         0
# interview_score    0
# salary             0
# dtype: int64

# %%
df.shape
# Out:
# (8, 4)

# %%
x = df.drop('salary', axis = 1)
y = df[['salary']]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
model = lr.fit(x,y)

# %%
import pickle

# %%
pickle.dump (model , open('maas.pkl','wb'))

# %%
# modeli eğitip kaydettikten sonra modeli tekrar yükleyip aşağıdaki gibi kullanıyoruz.

# %%
yenimodel = pickle.load(open('maas.pkl','rb'))

# %%
yenimodel.predict([[2,9,9]])
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[59821.68850073]])
