# %%
# Film tavsiyesi - Popularity Based

# %%
import pandas as pd

# %%
rating = pd.read_csv('ml-100k/ml-100k/u.data' , sep = '\t', header = None , names = ['user_id', 'movie_id' , 'rating'] , usecols=range(3))
# veriler virgülle ayrılmadığı için sep ile ayırma ifadesini seçtik , başlıkta eklemedikleri için header none seçtik , sütun isimlerini verdik, kolonları ayarladık usecol ile

# %%
rating.head()
# Out:
#    user_id  movie_id  rating
# 0      196       242       3
# 1      186       302       3
# 2       22       377       1
# 3      244        51       2
# 4      166       346       1

# %%
movies = pd.read_csv('ml-100k/ml-100k/u.item' , encoding =' iso-8859-1', sep = '|' , header = None , names = ['movie_id' , 'title'], usecols = range(2))

# %%
movies.head()
# Out:
#    movie_id              title
# 0         1   Toy Story (1995)
# 1         2   GoldenEye (1995)
# 2         3  Four Rooms (1995)
# 3         4  Get Shorty (1995)
# 4         5     Copycat (1995)

# %%
user = pd.read_csv('ml-100k/ml-100k/u.user' , sep = '|' , header = None , names = ['name_id' , 'Age' , 'Gender' ,'Profession ', 'Zipcode' ])

# %%
user
# Out:
#      name_id  Age Gender    Profession  Zipcode
# 0          1   24      M     technician   85711
# 1          2   53      F          other   94043
# 2          3   23      M         writer   32067
# 3          4   24      M     technician   43537
# 4          5   33      F          other   15213
# ..       ...  ...    ...            ...     ...
# 938      939   26      F        student   33319
# 939      940   32      M  administrator   02215
# 940      941   20      M        student   97229
# 941      942   48      F      librarian   78209
# 942      943   22      M        student   77841
#
# [943 rows x 5 columns]

# %%
# tabloları birleştircez

# %%
rating = pd.merge(movies , rating)

# %%
rating.head()
# Out:
#    movie_id             title  user_id  rating
# 0         1  Toy Story (1995)      308       4
# 1         1  Toy Story (1995)      287       5
# 2         1  Toy Story (1995)      148       4
# 3         1  Toy Story (1995)      280       4
# 4         1  Toy Story (1995)       66       3

# %%
rating.title.value_counts()
# Out:
# title
# Star Wars (1977)                        583
# Contact (1997)                          509
# Fargo (1996)                            508
# Return of the Jedi (1983)               507
# Liar Liar (1997)                        485
#                                        ...
# Invitation, The (Zaproszenie) (1986)      1
# Symphonie pastorale, La (1946)            1
# Nothing Personal (1995)                   1
# Ripe (1996)                               1
# Brother's Kiss, A (1997)                  1
# Name: count, Length: 1664, dtype: int64

# %%
import numpy as np

# %%
mg = rating.groupby('title').agg({'rating' : [np.size , np.sum , np.mean]})
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5784\1914487370.py:1: FutureWarning: The provided callable <function sum at 0x000001D803F796C0> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   mg = rating.groupby('title').agg({'rating' : [np.size , np.sum , np.mean]})
# C:\Users\USER\AppData\Local\Temp\ipykernel_5784\1914487370.py:1: FutureWarning: The provided callable <function mean at 0x000001D803F7AAC0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   mg = rating.groupby('title').agg({'rating' : [np.size , np.sum , np.mean]})

# %%
mg
# Out:
#                                       rating
#                                         size  sum      mean
# title
# 'Til There Was You (1997)                  9   21  2.333333
# 1-900 (1994)                               5   13  2.600000
# 101 Dalmatians (1996)                    109  317  2.908257
# 12 Angry Men (1957)                      125  543  4.344000
# 187 (1997)                                41  124  3.024390
# ...                                      ...  ...       ...
# Young Guns II (1990)                      44  122  2.772727
# Young Poisoner's Handbook, The (1995)     41  137  3.341463
# Zeus and Roxanne (1997)                    6   13  2.166667
# unknown                                    9   31  3.444444
# Á köldum klaka (Cold Fever) (1994)         1    3  3.000000
#
# [1664 rows x 3 columns]

# %%
pm = mg.sort_values(('rating' , 'mean'), ascending = False)

# %%
pm
# Out:
#                                                   rating
#                                                     size sum mean
# title
# Aiqing wansui (1994)                                   1   5  5.0
# Entertaining Angels: The Dorothy Day Story (1996)      1   5  5.0
# Santa with Muscles (1996)                              2  10  5.0
# Prefontaine (1997)                                     3  15  5.0
# They Made Me a Criminal (1939)                         1   5  5.0
# ...                                                  ...  ..  ...
# Pharaoh's Army (1995)                                  1   1  1.0
# August (1996)                                          1   1  1.0
# Babyfever (1994)                                       2   2  1.0
# Amityville: A New Generation (1993)                    5   5  1.0
# Woman in Question, The (1950)                          1   1  1.0
#
# [1664 rows x 3 columns]

# %%
gs = pm['rating']['sum'].sum()

# %%
gs
# Out:
# np.int64(352986)

# %%
pm['percentage'] = pm['rating']['sum'].div(gs)*100

# %%
pm.head()
# Out:
#                                                   rating          percentage
#                                                     size sum mean
# title
# Aiqing wansui (1994)                                   1   5  5.0   0.001416
# Entertaining Angels: The Dorothy Day Story (1996)      1   5  5.0   0.001416
# Santa with Muscles (1996)                              2  10  5.0   0.002833
# Prefontaine (1997)                                     3  15  5.0   0.004249
# They Made Me a Criminal (1939)                         1   5  5.0   0.001416

# %%
pm['rank'] = pm['percentage'].rank(ascending = False)

# %%
pm.sort_values(by='rank', ascending=True)
# Out:
#                                rating                 percentage    rank
#                                  size   sum      mean
# title
# Star Wars (1977)                  583  2541  4.358491   0.719859     1.0
# Fargo (1996)                      508  2111  4.155512   0.598041     2.0
# Return of the Jedi (1983)         507  2032  4.007890   0.575660     3.0
# Contact (1997)                    509  1936  3.803536   0.548464     4.0
# Raiders of the Lost Ark (1981)    420  1786  4.252381   0.505969     5.0
# ...                               ...   ...       ...        ...     ...
# Very Natural Thing, A (1974)        1     1  1.000000   0.000283  1636.0
# Low Life, The (1994)                1     1  1.000000   0.000283  1636.0
# Lotto Land (1995)                   1     1  1.000000   0.000283  1636.0
# Leopard Son, The (1996)             1     1  1.000000   0.000283  1636.0
# Mat' i syn (1997)                   1     1  1.000000   0.000283  1636.0
#
# [1664 rows x 5 columns]
