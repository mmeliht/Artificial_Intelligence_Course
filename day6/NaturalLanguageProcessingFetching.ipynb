# %% [markdown]
# # Natural Language Processing - Doğal Dil İşleme - Fetching Text Data

# %% [markdown]
# ### Tools for fetching Text Data
# + Docx word
# + PDF
# + Text
# + Website
# + API
# + Database
# + NOSQL

# %%
#pip install docx2txt

# %%
import docx2txt as wd

# %%
kosey = wd.process('boszaman.docx')

# %%
kosey

# %%
for p in kosey.split('\n\n'):
    print(p)

# %%
dir(kosey)

# %%
# kosey.split()

# %%
# kosey.count('yapay')

# %%
#pip install python-docx

# %%
import docx

# %%
kosey2 = docx.Document('boszaman.docx')

# %%
for p in kosey2.paragraphs :
    print(p.text)

# %%
#pip install pypdf2

# %%
import PyPDF2 as pr

# %%
pdfdoc = pr.PdfReader('nlp_example.pdf')

# %%
len(pdfdoc.pages)
# Out:
# 2

# %%
page1 = pdfdoc.pages[0]

# %%
page1.extract_text()

# %%
with open('challenge.txt') as f:
    file = f.read()

# %%
file

# %%
url = 'https://en.wikipedia.org/wiki/Natural_language_processing'

# %%
import requests as rq

# %%
yazi = rq.get(url)

# %%
yazi.text

# %%
from bs4 import BeautifulSoup as bs # kotu gorunumlu HTML kodunu okunabilir hale getirir

# %%
corba = bs(yazi.text, 'lxml')

# %%
corba

# %%
for p in corba.find_all('p'):
    print(p.text)

# %%
#pip install wikipedia

# %%
import wikipedia as wp

# %%
wp.search('Quantum Computer')
# Out:
# ['Quantum computing',
#  'Topological quantum computer',
#  "India's quantum computer",
#  'Sycamore processor',
#  'Trapped-ion quantum computer',
#  'Post-quantum cryptography',
#  'Jiuzhang (quantum computer)',
#  'Kane quantum computer',
#  'Nuclear magnetic resonance quantum computer',
#  'Quantum Turing machine']

# %%
page= wp.page('Quantum Computer')

# %%
page.title
# Out:
# 'Quantum computing'

# %%
page.content
