# %% [markdown]
# # Natural Language Processing - Doğal Dil İşleme - Fetching Text Data

# %% [markdown]
# ### Tools for fetching Text Data
# + Docx word
# + PDF
# + Text
# + Website
# + API
# + Database
# + NOSQL

# %%
#pip install docx2txt

# %%
import docx2txt as wd

# %%
kosey = wd.process('boszaman.docx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 kosey = wd.process('boszaman.docx')
#
# File ~\anaconda3\Lib\site-packages\docx2txt\docx2txt.py:76, in process(docx, img_dir)
#      73 text = u''
#      75 # unzip the docx in memory
# ---> 76 zipf = zipfile.ZipFile(docx)
#      77 filelist = zipf.namelist()
#      79 # get header text
#      80 # there can be 3 header files in the zip
#
# File ~\anaconda3\Lib\zipfile\__init__.py:1367, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1365 while True:
#    1366     try:
# -> 1367         self.fp = io.open(file, filemode)
#    1368     except OSError:
#    1369         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'boszaman.docx'
