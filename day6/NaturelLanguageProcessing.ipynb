# %% [markdown]
# # NLP Data Analysis

# %%
#pip install nltk

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %% [markdown]
# ### Tokenization

# %%
text = "bu şehir bir başkadır. Herhkes beni aldattı gitti .kamyonlar yine kavun taşır fakat içimdeki şarkı bitti"

# %%
text.split() # text tokenization
# Out:
# ['bu',
#  'şehir',
#  'bir',
#  'başkadır.',
#  'Herhkes',
#  'beni',
#  'aldattı',
#  'gitti',
#  '.kamyonlar',
#  'yine',
#  'kavun',
#  'taşır',
#  'fakat',
#  'içimdeki',
#  'şarkı',
#  'bitti']

# %%
text.split('.') # sentence tokenization
# Out:
# ['bu şehir bir başkadır',
#  ' Herhkes beni aldattı gitti ',
#  'kamyonlar yine kavun taşır fakat içimdeki şarkı bitti']

# %%
text.upper()
# Out:
# 'BU ŞEHIR BIR BAŞKADIR. HERHKES BENI ALDATTI GITTI .KAMYONLAR YINE KAVUN TAŞIR FAKAT IÇIMDEKI ŞARKI BITTI'

# %%
from nltk.tokenize import word_tokenize, sent_tokenize , WordPunctTokenizer , TreebankWordTokenizer

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
word_tokenize(text)
# Out:
# ['bu',
#  'şehir',
#  'bir',
#  'başkadır',
#  '.',
#  'Herhkes',
#  'beni',
#  'aldattı',
#  'gitti',
#  '.kamyonlar',
#  'yine',
#  'kavun',
#  'taşır',
#  'fakat',
#  'içimdeki',
#  'şarkı',
#  'bitti']

# %%
sent_tokenize(text)
# Out:
# ['bu şehir bir başkadır.',
#  'Herhkes beni aldattı gitti .kamyonlar yine kavun taşır fakat içimdeki şarkı bitti']

# %%
# Stopwords // am is are // gereksiz kelimeler
